# %% [markdown]
# # Comparação entre Espanha e Itália, e suas regiões

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import gc
from scipy.signal import find_peaks
import sys
from pandas import datetime
reload(sys)  
sys.setdefaultencoding('utf8')

# %%
PATH_DATA_es = '/Users/joaomacedo/Desktop/MiEI/AAII/novo/serie_historica_acumulados.csv'
PATH_DATA_it = '/Users/joaomacedo/Desktop/MiEI/AAII/novo/dpc-covid19-ita-regioni2.csv'

# %% [markdown]
# ## Preparação dos dados

# %%
d_name_es = {
'AN':'Andalucía',
'AR':'Aragón',
'AS':'Asturias',
'IB':'Baleares',
'CN':'Canarias',
'CB':'Cantabria',
'CM':'Castilla La Mancha',
'CL':'Castilla y León',
'CT':'Cataluña',
'CE':'Ceuta',
'VC':'C. Valenciana',
'EX':'Extremadura',
'GA':'Galicia',
'MD':'Madrid',
'ML':'Melilla',
'MC':'Murcia',
'NC':'Navarra',
'PV':'País Vasco',
'RI':'La Rioja'
}

d_ccaa_es = {
'Andalucía': 'Andalucía',
'Aragón': 'Aragón',
'Asturias': 'Principado de Asturias',
'Baleares': 'Islas Baleares',
'Canarias': 'Islas Canarias',
'Cantabria':'Cantabria',
'Castilla La Mancha': 'Castilla-La Mancha',
'Castilla y León': 'Castilla y León',
'Cataluña': 'Cataluña',
'Ceuta': 'Ceuta y Melilla',
'C. Valenciana': 'Comunidad Valenciana',
'Extremadura': 'Extremadura',
'Galicia': 'Galicia',
'Madrid': 'Comunidad de Madrid',
'Melilla': 'Ceuta y Melilla',
'Murcia': 'Región de Murcia',
'Navarra': 'Comunidad Foral de Navarra',
'País Vasco': 'País Vasco',
'La Rioja': 'La Rioja'
}

d_ccaa_id_es = {
'Andalucía': "1",
'Aragón' : "2",
'Principado de Asturias': "3",
'Islas Baleares': "4",
'Islas Canarias': "5",
'Cantabria': "6",
'Castilla-La Mancha': "7",
'Castilla y León': "8",
'Cataluña': "9",
'Ceuta y Melilla': "10",
'Comunidad Valenciana': "11",
'Extremadura': "12",
'Galicia': "13",
'Comunidad de Madrid' : "14",
'Ceuta y Melilla': "15",
'Región de Murcia': "16",
'Comunidad Foral de Navarra': "17",
'País Vasco': "18",
'La Rioja': "19"
}

d_ccaa_population_es = {
'Andalucía': 8414240,
'Aragón' : 1319291,
'Principado de Asturias': 1022800,
'Islas Baleares': 1149460,
'Islas Canarias': 2153389,
'Cantabria': 581078,
'Castilla-La Mancha': 2032863,
'Castilla y León': 2399548,
'Cataluña': 7675217,
'Ceuta y Melilla': 171264,
'Comunidad Valenciana': 5003769,
'Extremadura': 1067710,
'Galicia': 2699499,
'Comunidad de Madrid' : 6663394,
'Ceuta y Melilla': 171264,
'Región de Murcia': 1493898,
'Comunidad Foral de Navarra': 654214,
'País Vasco': 2207776,
'La Rioja': 316798
}

d_name_it = {
'Abruzzo': 'Abruzzo',
'Basilicata': 'Basilicata',
'Calabria': 'Calabria',
'Campania': 'Campania',
'Emilia-Romagna': 'Emilia-Romagna',
'Friuli Venezia Giulia': 'Friuli Venezia Giulia',
'Lazio': 'Lazio',
'Liguria': 'Liguria',
'Lombardia': 'Lombardia',
'Marche': 'Marche',
'Molise': 'Molise',
'Piemonte': 'Piemonte',
'Puglia': 'Puglia',
'Sardegna': 'Sardegna',
'Sicilia': 'Sicilia',
'Toscana': 'Toscana',
'P.A. Bolzano': 'P.A. Bolzano',
'P.A. Trento': 'P.A. Trento',
'Umbria': 'Umbria' ,
'Valle d\'Aosta': 'Valle d\'Aosta',
'Veneto': 'Veneto'
}

regione_id_it = {
'Abruzzo': 1,
'Basilicata' : 2,
'Calabria': 3,
'Campania': 4,
'Emilia-Romagna': 5,
'Friuli Venezia Giulia': 6,
'Lazio': 7,
'Liguria': 8,
'Lombardia': 9,
'Marche': 10,
'Molise': 11,
'Piemonte': 12,
'Puglia': 13,
'Sardegna' : 14,
'Sicilia': 15,
'Toscana': 16,
'P.A. Bolzano': 17,
'P.A. Trento': 18,
'Umbria' : 19,
'Valle d\'Aosta': 20,
'Veneto': 21
}

regione_pop_it = {
'Abruzzo': 1311580,
'Basilicata' : 562869,
'Calabria': 1947131,
'Campania': 5801692,
'Emilia-Romagna': 4459477,
'Friuli Venezia Giulia': 1215220,
'Lazio': 5879082,
'Liguria': 1550640,
'Lombardia': 10060574,
'Marche': 1525271,
'Molise': 305617,
'Piemonte': 4356406,
'Puglia': 4029053,
'Sardegna' : 1639591,
'Sicilia': 4999891,
'Toscana': 3729641,
'P.A. Bolzano': 520891,
'P.A. Trento': 117417,
'Umbria' : 882015,
'Valle d\'Aosta': 125666,
'Veneto': 4905854
}

# %% [markdown]
# ## Importar os dataframe
# Preparação dos dados

# %%
df_it = pd.read_csv(PATH_DATA_it, encoding='latin-1')
df_it.fillna(0, inplace = True)
df_it["CCAA"] = df_it["denominazione_regione"].map(d_name_it)
df_it["CCAA_for_Folium"] = df_it["denominazione_regione"].map(d_name_it)
df_it["id"] = df_it["CCAA_for_Folium"].map(regione_id_it)

df_it["Population"] = df_it["CCAA_for_Folium"].map(regione_pop_it)

df_it.rename(columns = {"data":"DATE",
                    "totale_casi":"TOTAL_INFECTED",
                    "totale_ospedalizzati":"REQUIERED_HOSPITALIZATION",
                    "terapia_intensiva":"REQUIERED_ADVANCED_CARE",
                    "deceduti":"TOTAL_DEATHS",
                    "dimessi_guariti":"CURED"}, inplace = True)
df_it["CCAA"].isnull().sum()
# Out:
# 0

# %%
df_es = pd.read_csv(PATH_DATA_es, encoding='latin-1')
df_es.fillna(0, inplace = True)
df_es["CCAA"] = df_es["CCAA"].map(d_name_es)
df_es["CCAA_for_Folium"] = df_es["CCAA"].map(d_ccaa_es)
df_es["id"] = df_es["CCAA_for_Folium"].map(d_ccaa_id_es)

df_es["Population"] = df_es["CCAA_for_Folium"].map(d_ccaa_population_es)


df_es.rename(columns = {"FECHA":"DATE",
                    "CASOS":"TOTAL_INFECTED",
                    "Hospitalizados":"REQUIERED_HOSPITALIZATION",
                    "UCI":"REQUIERED_ADVANCED_CARE",
                    "Fallecidos":"TOTAL_DEATHS",
                    "Recuperados":"CURED"}, inplace = True)

# %%
df_es["CCAA"].isnull().sum()
# Out:
# 5

# %%
df_es.dropna(inplace = True, axis = "rows") # apagar o texto no fim do ficheiro
df_es["CCAA"].isnull().sum()
# Out:
# 0

# %%
def correct_date_es(date_str):
    list_dates = date_str.split("/")
    day = list_dates[0]
    month = list_dates[1]
    year = list_dates[2]
    
    if len(day) == 1:
        day = "0" + day
    if len(month) == 1:
        month = "0" + month
        
    return "/".join([day, month, year])

def correct_date_it(date_str):
    list_dates = date_str.split("-")
    day = list_dates[2]
    month = list_dates[1]
    year = list_dates[0]
        
    return "/".join([day, month, year])

# %%
df_es["NEW_DATE"] = df_es["DATE"].apply(correct_date_es)
df_es["DATE"] = pd.to_datetime(df_es["NEW_DATE"], format='%d/%m/%Y')
df_es = df_es[["id", "CCAA", "DATE", "TOTAL_INFECTED", "REQUIERED_HOSPITALIZATION", "REQUIERED_ADVANCED_CARE", "TOTAL_DEATHS", "CURED","Population"]]
df_es["id"].astype(np.int16)
df_es.head()
# Out:
#   id       CCAA       DATE  TOTAL_INFECTED  REQUIERED_HOSPITALIZATION  \
# 0  1  Andalucía 2020-02-20             0.0                        0.0
# 1  2     Aragón 2020-02-20             0.0                        0.0
# 2  3   Asturias 2020-02-20             0.0                        0.0
# 3  4   Baleares 2020-02-20             1.0                        0.0
# 4  5   Canarias 2020-02-20             1.0                        0.0
#
#    REQUIERED_ADVANCED_CARE  TOTAL_DEATHS  CURED  Population
# 0                      0.0           0.0    0.0   8414240.0
# 1                      0.0           0.0    0.0   1319291.0
# 2                      0.0           0.0    0.0   1022800.0
# 3                      0.0           0.0    0.0   1149460.0
# 4                      0.0           0.0    0.0   2153389.0

# %%
df_it["NEW_DATE"] = df_it["DATE"].apply(correct_date_it)
df_it["DATE"] = pd.to_datetime(df_it["NEW_DATE"], format='%d/%m/%Y')
df_it = df_it[["id", "CCAA", "DATE", "TOTAL_INFECTED", "REQUIERED_HOSPITALIZATION", "REQUIERED_ADVANCED_CARE", "TOTAL_DEATHS", "CURED","Population"]]
df_it["id"].astype(np.int16)
df_it.head()
# Out:
#    id          CCAA       DATE  TOTAL_INFECTED  REQUIERED_HOSPITALIZATION  \
# 0   1       Abruzzo 2020-02-24               0                          0
# 1   2    Basilicata 2020-02-24               0                          0
# 2  17  P.A. Bolzano 2020-02-24               0                          0
# 3   3      Calabria 2020-02-24               0                          0
# 4   4      Campania 2020-02-24               0                          0
#
#    REQUIERED_ADVANCED_CARE  TOTAL_DEATHS  CURED  Population
# 0                        0             0      0     1311580
# 1                        0             0      0      562869
# 2                        0             0      0      520891
# 3                        0             0      0     1947131
# 4                        0             0      0     5801692

# %%
df_es["Infected_1000h"] = df_es["TOTAL_INFECTED"]/(df_es["Population"]/1000)
df_es["Mortality_rate"] = df_es["TOTAL_DEATHS"] / df_es["TOTAL_INFECTED"]
df_es.fillna(0, inplace = True)
df_es.head()
# Out:
#   id       CCAA       DATE  TOTAL_INFECTED  REQUIERED_HOSPITALIZATION  \
# 0  1  Andalucía 2020-02-20             0.0                        0.0
# 1  2     Aragón 2020-02-20             0.0                        0.0
# 2  3   Asturias 2020-02-20             0.0                        0.0
# 3  4   Baleares 2020-02-20             1.0                        0.0
# 4  5   Canarias 2020-02-20             1.0                        0.0
#
#    REQUIERED_ADVANCED_CARE  TOTAL_DEATHS  CURED  Population  Infected_1000h  \
# 0                      0.0           0.0    0.0   8414240.0        0.000000
# 1                      0.0           0.0    0.0   1319291.0        0.000000
# 2                      0.0           0.0    0.0   1022800.0        0.000000
# 3                      0.0           0.0    0.0   1149460.0        0.000870
# 4                      0.0           0.0    0.0   2153389.0        0.000464
#
#    Mortality_rate
# 0             0.0
# 1             0.0
# 2             0.0
# ...

# %%
df_it["Infected_1000h"] = df_it["TOTAL_INFECTED"]/(df_it["Population"]/1000)
df_it["Mortality_rate"] = df_it["TOTAL_DEATHS"] / df_it["TOTAL_INFECTED"]
df_it.fillna(0, inplace = True)
df_it.head()
# Out:
#    id          CCAA       DATE  TOTAL_INFECTED  REQUIERED_HOSPITALIZATION  \
# 0   1       Abruzzo 2020-02-24               0                          0
# 1   2    Basilicata 2020-02-24               0                          0
# 2  17  P.A. Bolzano 2020-02-24               0                          0
# 3   3      Calabria 2020-02-24               0                          0
# 4   4      Campania 2020-02-24               0                          0
#
#    REQUIERED_ADVANCED_CARE  TOTAL_DEATHS  CURED  Population  Infected_1000h  \
# 0                        0             0      0     1311580             0.0
# 1                        0             0      0      562869             0.0
# 2                        0             0      0      520891             0.0
# 3                        0             0      0     1947131             0.0
# 4                        0             0      0     5801692             0.0
#
#    Mortality_rate
# 0             0.0
# 1             0.0
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,10))

for ccaa in sorted(list(df_es["CCAA"].unique())):
    
    x = df_es["DATE"].unique()
    y = df_es[df_es["CCAA"] == ccaa]["TOTAL_INFECTED"]
    y_log = np.log(y)
    
    ax1.plot(x, y, label = ccaa)
    ax1.set_title("Total infetados Espanha (escala normal)")
    ax1.legend()

    ax2.plot(x, y_log, label = ccaa)
    ax2.set_title("Total infetados Espanha (escala log)")
    ax2.legend()
        
for ax in fig.axes:
    matplotlib.pyplot.sca(ax)
    plt.xticks(rotation=90)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,10))

for ccaa in sorted(list(df_it["CCAA"].unique())):
    
    x = df_it["DATE"].unique()
    y = df_it[df_it["CCAA"] == ccaa]["TOTAL_INFECTED"]
    y_log = np.log(y)
    
    ax1.plot(x, y, label = ccaa)
    ax1.set_title("Total infetados Italia (escala normal)")
    ax1.legend()

    ax2.plot(x, y_log, label = ccaa)
    ax2.set_title("Total infetados Italia (escala log)")
    ax2.legend()
        
for ax in fig.axes:
    matplotlib.pyplot.sca(ax)
    plt.xticks(rotation=90)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,10))

for ccaa in sorted(list(df_es["CCAA"].unique())):
    
    x = df_es["DATE"].unique()
    y = df_es[df_es["CCAA"] == ccaa]["TOTAL_DEATHS"]
    y_log = np.log(y)
    
    ax1.plot(x, y, label = ccaa)
    ax1.set_title("Total de mortes em Espanha (escala normal)")
    ax1.legend()

    ax2.plot(x, y_log, label = ccaa)
    ax2.set_title("Total de mortes em Espanha (escala log)")
    ax2.legend()
        
for ax in fig.axes:
    matplotlib.pyplot.sca(ax)
    plt.xticks(rotation=90)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,10))

for ccaa in sorted(list(df_it["CCAA"].unique())):
    
    x = df_it["DATE"].unique()
    y = df_it[df_it["CCAA"] == ccaa]["TOTAL_DEATHS"]
    y_log = np.log(y)
    
    ax1.plot(x, y, label = ccaa)
    ax1.set_title("Total de mortes em Italia (escala normal)")
    ax1.legend()

    ax2.plot(x, y_log, label = ccaa)
    ax2.set_title("Total de mortes em Italia (escala log)")
    ax2.legend()
        
for ax in fig.axes:
    matplotlib.pyplot.sca(ax)
    plt.xticks(rotation=90)

# %%
plt.figure(figsize = (20, 10))

for ccaa in sorted(list(df_es["CCAA"].unique())):
    
    x = df_es["DATE"].unique()
    y = df_es[df_es["CCAA"] == ccaa]["Mortality_rate"]
    
    plt.plot(x, y, label = ccaa)
    plt.title("Evolucao da mortalidade ao longo do tempo em Espanha")
    plt.legend()
    plt.xticks(rotation=90)

# %%
plt.figure(figsize = (20, 10))

for ccaa in sorted(list(df_it["CCAA"].unique())):
    
    x = df_it["DATE"].unique()
    y = df_it[df_it["CCAA"] == ccaa]["Mortality_rate"]
    
    plt.plot(x, y, label = ccaa)
    plt.title("Evolucao da mortalidade ao longo do tempo em Italia")
    plt.legend()
    plt.xticks(rotation=90)

# %%
# create the pivot table of total cases
total_df_es = df_es.set_index("DATE").resample("D")[["TOTAL_INFECTED", "REQUIERED_HOSPITALIZATION", "REQUIERED_ADVANCED_CARE", "TOTAL_DEATHS", "CURED","Population"]].sum()
total_df_es = total_df_es[total_df_es["Population"] > 0]
total_df_es["TOTAL_INFECTED_1000H"] = total_df_es["TOTAL_INFECTED"]/(total_df_es["Population"]/1000)
total_df_es["TOTAL_DEATHS_1000H"] = total_df_es["TOTAL_DEATHS"]/(total_df_es["Population"]/1000)

# get the data
x = list(total_df_es.index)
y_1 = list(total_df_es["TOTAL_INFECTED_1000H"]) # 1 axis
y_2 = list(total_df_es["TOTAL_DEATHS_1000H"]) # 2 axis

# create the figures
fig, ax = plt.subplots(figsize = (15, 7))
plot1 = ax.plot(x, y_1, color = "r", label = "Total de infetados por 1000 habitantes") # plot the first data
plt.xticks(rotation=90) # rotate the date

ax2 = ax.twinx() # create a secondary axis
plot2 = ax2.plot(x, y_2, color = "k", label = "Total de mortes por 1000 habitantes") # plot the second data
fig.tight_layout()
plt.title("Evolucao do total de casos infetados e total de mortes por 1000 habitantes em Espanha")

# create a common legend
lns = plot1 + plot2
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0)

# prettify
ax.grid()
ax.set_xlabel("Data")
ax.set_ylabel("Relacao do total de infetados por 1000 habitantes")
ax2.set_ylabel("Relacao do total de mortes por 1000 habitantes")
# Out:
# Text(998.875,0.5,'Relacao do total de mortes por 1000 habitantes')

# %% [markdown]
# Evolução global de todos os casos em Espanha

# %%
# create the pivot table of total cases
total_df_it = df_it.set_index("DATE").resample("D")[["TOTAL_INFECTED", "REQUIERED_HOSPITALIZATION", "REQUIERED_ADVANCED_CARE", "TOTAL_DEATHS", "CURED","Population"]].sum()
total_df_it = total_df_it[total_df_it["Population"] > 0]
total_df_it["TOTAL_INFECTED_1000H"] = total_df_it["TOTAL_INFECTED"]/(total_df_it["Population"]/1000)
total_df_it["TOTAL_DEATHS_1000H"] = total_df_it["TOTAL_DEATHS"]/(total_df_it["Population"]/1000)

# get the data
x = list(total_df_it.index)
y_1 = list(total_df_it["TOTAL_INFECTED_1000H"]) # 1 axis
y_2 = list(total_df_it["TOTAL_DEATHS_1000H"]) # 2 axis

# create the figures
fig, ax = plt.subplots(figsize = (15, 7))
plot1 = ax.plot(x, y_1, color = "r", label = "Total de infetados por 1000 habitantes") # plot the first data
plt.xticks(rotation=90) # rotate the date

ax2 = ax.twinx() # create a secondary axis
plot2 = ax2.plot(x, y_2, color = "k", label = "Total de mortes por 1000 habitantes") # plot the second data
fig.tight_layout()
plt.title("Evalucao do total de casos infetados e total de mortes por 1000 habitantes em Italia")

# create a common legend
lns = plot1 + plot2
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0)

# prettify
ax.grid()
ax.set_xlabel("Data")
ax.set_ylabel("Relacao do total de infetados por 1000 habitantes")
ax2.set_ylabel("Relacao do total de mortes por 1000 habitantes")
# Out:
# Text(998.875,0.5,'Relacao do total de mortes por 1000 habitantes')

# %% [markdown]
# Evolução global de todos os casos em Espanha

# %%
total_df_es["TOTAL_INFECTED	REQUIERED_HOSPITALIZATION	REQUIERED_ADVANCED_CARE	TOTAL_DEATHS	CURED".split()].plot(figsize =(15, 5))

# %% [markdown]
# Evolução global de todos os casos em Italia

# %%
total_df_it["TOTAL_INFECTED	REQUIERED_HOSPITALIZATION	REQUIERED_ADVANCED_CARE	TOTAL_DEATHS	CURED".split()].plot(figsize =(15, 5))

# %%
short_df = df_es[df_es["DATE"] == max(df_es["DATE"])][["CCAA", "Mortality_rate"]].sort_values("Mortality_rate", ascending = False)
x = short_df["CCAA"]
y = short_df["Mortality_rate"]

mean_y = np.mean(y)
mean_y

plt.figure(figsize = (10, 5))
plt.scatter(x, y, c= "red", alpha = 0.5)
plt.title("Taxa de mortalidade por regiao em Espanha")

plt.xticks(rotation=90)
plt.axhline(mean_y, c = "k", alpha = 0.5, lw = 1)
plt.annotate('Mortalidade media: {}%'.format(round(mean_y*100, 2)),
        xy=(12, mean_y),
        xycoords='data',
        xytext=(50, 50), 
        textcoords='offset points',
        arrowprops=dict(arrowstyle="->", color = "k", alpha = 0.5),
        color = "k")
# Out:
# Text(50,50,'Mortalidade media: 8.54%')

# %%
short_df = df_it[df_it["DATE"] == max(df_it["DATE"])][["CCAA", "Mortality_rate"]].sort_values("Mortality_rate", ascending = False)
x = short_df["CCAA"]
y = short_df["Mortality_rate"]

mean_y = np.mean(y)
mean_y

plt.figure(figsize = (10, 5))
plt.scatter(x, y, c= "red", alpha = 0.5)
plt.title("Taxa de mortalidade por regiao em Italia")

plt.xticks(rotation=90)
plt.axhline(mean_y, c = "k", alpha = 0.5, lw = 1)
plt.annotate('Mortalidade media: {}%'.format(round(mean_y*100, 2)),
        xy=(12, mean_y),
        xycoords='data',
        xytext=(50, 50), 
        textcoords='offset points',
        arrowprops=dict(arrowstyle="->", color = "k", alpha = 0.5),
        color = "k")
# Out:
# Text(50,50,'Mortalidade media: 10.46%')

# %% [markdown]
# Vamos ver a evolução de cada tipo de casos em aumento percentual.
#
# Para fazer isso, primeiro precisamos de criar todas as colunas.

# %%
column_of_interest = "TOTAL_INFECTED"
total_df_es["Increase_%_{}".format(column_of_interest)] = (total_df_es[column_of_interest] - total_df_es[column_of_interest].shift(1))/(total_df_es[column_of_interest].shift(1))

column_of_interest = "REQUIERED_HOSPITALIZATION"
total_df_es["Increase_%_{}".format(column_of_interest)] = (total_df_es[column_of_interest] - total_df_es[column_of_interest].shift(1))/(total_df_es[column_of_interest].shift(1))

column_of_interest = "REQUIERED_ADVANCED_CARE"
total_df_es["Increase_%_{}".format(column_of_interest)] = (total_df_es[column_of_interest] - total_df_es[column_of_interest].shift(1))/(total_df_es[column_of_interest].shift(1))

column_of_interest = "TOTAL_DEATHS"
total_df_es["Increase_%_{}".format(column_of_interest)] = (total_df_es[column_of_interest] - total_df_es[column_of_interest].shift(1))/(total_df_es[column_of_interest].shift(1))

column_of_interest = "CURED"
total_df_es["Increase_%_{}".format(column_of_interest)] = (total_df_es[column_of_interest] - total_df_es[column_of_interest].shift(1))/(total_df_es[column_of_interest].shift(1))

total_df_es.fillna(0, inplace = True)
total_df_es.replace([np.inf, -np.inf], 0, inplace = True)

# %%
l_c = [
'Increase_%_TOTAL_INFECTED',
'Increase_%_REQUIERED_HOSPITALIZATION',
'Increase_%_REQUIERED_ADVANCED_CARE',
'Increase_%_TOTAL_DEATHS',
'Increase_%_CURED'
]

colors = [
"red",
"orange",
"magenta",
"black",
"green"
]

fig, axes = plt.subplots(5, 1, figsize = (15, 20), sharex = True)

x = total_df_es.index

for ax, col, color in zip(axes, l_c, colors):
    
    y = total_df_es[col]
    
    ax.plot(x, y, color = color)
    
    # prettify
    ax.grid()
    ax.set_title(" ".join(list(map(str.title, col.split("_"))))) # convert this Increase_%_TOTAL_INFECTED to this Increase % Total Infected

ax.tick_params(labelrotation=90)
fig.text(0.5, 0.04, 'Date', ha='center', fontsize=14)
fig.text(0.04, 0.5, 'Espanha', va='center', fontsize=14, rotation='vertical')
# Out:
# Text(0.04,0.5,'Espanha')

# %%
column_of_interest = "TOTAL_INFECTED"
total_df_it["Increase_%_{}".format(column_of_interest)] = (total_df_it[column_of_interest] - total_df_it[column_of_interest].shift(1))/(total_df_it[column_of_interest].shift(1))

column_of_interest = "REQUIERED_HOSPITALIZATION"
total_df_it["Increase_%_{}".format(column_of_interest)] = (total_df_it[column_of_interest] - total_df_it[column_of_interest].shift(1))/(total_df_it[column_of_interest].shift(1))

column_of_interest = "REQUIERED_ADVANCED_CARE"
total_df_it["Increase_%_{}".format(column_of_interest)] = (total_df_it[column_of_interest] - total_df_it[column_of_interest].shift(1))/(total_df_it[column_of_interest].shift(1))

column_of_interest = "TOTAL_DEATHS"
total_df_it["Increase_%_{}".format(column_of_interest)] = (total_df_it[column_of_interest] - total_df_it[column_of_interest].shift(1))/(total_df_it[column_of_interest].shift(1))

column_of_interest = "CURED"
total_df_it["Increase_%_{}".format(column_of_interest)] = (total_df_it[column_of_interest] - total_df_it[column_of_interest].shift(1))/(total_df_it[column_of_interest].shift(1))

total_df_it.fillna(0, inplace = True)
total_df_it.replace([np.inf, -np.inf], 0, inplace = True)

fig, axes = plt.subplots(5, 1, figsize = (15, 20), sharex = True)

x = total_df_it.index

for ax, col, color in zip(axes, l_c, colors):
    
    y = total_df_it[col]
    
    ax.plot(x, y, color = color)
    
    # prettify
    ax.grid()
    ax.set_title(" ".join(list(map(str.title, col.split("_"))))) # convert this Increase_%_TOTAL_INFECTED to this Increase % Total Infected

ax.tick_params(labelrotation=90)
fig.text(0.5, 0.04, 'Date', ha='center', fontsize=14)
fig.text(0.04, 0.5, 'Italia', va='center', fontsize=14, rotation='vertical')
# Out:
# Text(0.04,0.5,'Italia')

# %% [markdown]
# Nas próximas visualizações, será mostrado o total de casos infectados para cada região tanto em Espanha como Itália numa escala normal e também numa escala logarítmica.

# %%
x = [day for day in range(len(df_es["DATE"].unique()))]

fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(30,20))
# plt.setp(axes, ylim=(0 ,max(df["Mortality rate"])))
ccaas = list(df_es["CCAA"].unique())

i = 0

for col_axes in axes:
    for ax in col_axes:
        if i < len(ccaas):
            ccaa = ccaas[i]
            y = df_es[df_es["CCAA"] == ccaa]["TOTAL_INFECTED"].values
            
            plot1 = ax.plot(x, y, color = "k", alpha = 0.7, label = "Escala normal de casos infectados")
            
            ax2 = ax.twinx() # create a secondary axis
            plot2 = ax2.plot(x, np.log(y), color = "r", label = "Escala logaritmica de casos infectados") # plot the second data
            
            # create a common legend
            lns = plot1 + plot2
            labs = [l.get_label() for l in lns]
            ax.legend(lns, labs, loc=0)

            # prettify
            ax.grid()
            ax.set_xlabel("N de dias")
            ax.set_ylabel("Escala Normal")
            ax2.set_ylabel("Escala Log")
            plt.title("Casos infectados ao longo do tempo em {}".format(ccaa))
            plt.tight_layout()
            
            i += 1

fig.delaxes(axes[3, 4])

# %%
x = [day for day in range(len(df_it["DATE"].unique()))]

fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(30,20))
# plt.setp(axes, ylim=(0 ,max(df["Mortality rate"])))
ccaas = list(df_it["CCAA"].unique())

i = 0

for col_axes in axes:
    for ax in col_axes:
        if i < len(ccaas):
            ccaa = ccaas[i]
            y = df_it[df_it["CCAA"] == ccaa]["TOTAL_INFECTED"].values
            
            plot1 = ax.plot(x, y, color = "k", alpha = 0.7, label = "Escala normal de casos infectados")
            
            ax2 = ax.twinx() # create a secondary axis
            plot2 = ax2.plot(x, np.log(y), color = "r", label = "Escala logaritmica de casos infectados") # plot the second data
            
            # create a common legend
            lns = plot1 + plot2
            labs = [l.get_label() for l in lns]
            ax.legend(lns, labs, loc=0)

            # prettify
            ax.grid()
            ax.set_xlabel("N de dias")
            ax.set_ylabel("Escala Normal")
            ax2.set_ylabel("Escala Log")
            plt.title("Casos infectados ao longo do tempo em {}".format(ccaa))
            plt.tight_layout()
            
            i += 1

fig.delaxes(axes[3, 4])

# %% [markdown]
# Nas próximas visualizações, será mostrado o total de mortes para cada região tanto em Espanha como Itália numa escala normal e também numa escala logarítmica.

# %%
x = [day for day in range(len(df_es["DATE"].unique()))]

fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(30,20))
# plt.setp(axes, ylim=(0 ,max(df["Mortality rate"])))
ccaas = list(df_es["CCAA"].unique())

i = 0

for col_axes in axes:
    for ax in col_axes:
        if i < len(ccaas):
            ccaa = ccaas[i]
            y = df_es[df_es["CCAA"] == ccaa]["TOTAL_DEATHS"].values
            
            plot1 = ax.plot(x, y, color = "k", alpha = 0.7, label = "Escala normal de mortes")
            
            ax2 = ax.twinx() # create a secondary axis
            plot2 = ax2.plot(x, np.log(y), color = "r", label = "Escala logaritmica de mortes") # plot the second data
            
            # create a common legend
            lns = plot1 + plot2
            labs = [l.get_label() for l in lns]
            ax.legend(lns, labs, loc=0)

            # prettify
            ax.grid()
            ax.set_xlabel("N de dias")
            ax.set_ylabel("Escala normal")
            ax2.set_ylabel("Escala log")
            plt.title("Mortes ao longo do tempo em {}".format(ccaa))
            plt.tight_layout()
            
            i += 1

fig.delaxes(axes[3, 4])

# %%
x = [day for day in range(len(df_it["DATE"].unique()))]

fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(30,20))
# plt.setp(axes, ylim=(0 ,max(df["Mortality rate"])))
ccaas = list(df_it["CCAA"].unique())

i = 0

for col_axes in axes:
    for ax in col_axes:
        if i < len(ccaas):
            ccaa = ccaas[i]
            y = df_it[df_it["CCAA"] == ccaa]["TOTAL_DEATHS"].values
            
            plot1 = ax.plot(x, y, color = "k", alpha = 0.7, label = "Escala normal de mortes")
            
            ax2 = ax.twinx() # create a secondary axis
            plot2 = ax2.plot(x, np.log(y), color = "r", label = "Escala logaritmica de mortes") # plot the second data
            
            # create a common legend
            lns = plot1 + plot2
            labs = [l.get_label() for l in lns]
            ax.legend(lns, labs, loc=0)

            # prettify
            ax.grid()
            ax.set_xlabel("N de dias")
            ax.set_ylabel("Escala normal")
            ax2.set_ylabel("Escala log")
            plt.title("Mortes ao longo do tempo em {}".format(ccaa))
            plt.tight_layout()
            
            i += 1

fig.delaxes(axes[3, 4])

# %% [markdown]
# Nas próximas visualizações, será mostrado a taxa de mortalidade para cada região tanto em Espanha como Itália.

# %%
x = [day for day in range(len(df_es["DATE"].unique()))]

fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(30,20))
# plt.setp(axes, ylim=(0 ,max(df["Mortality rate"])))
ccaas = list(df_es["CCAA"].unique())

i = 0

for col_axes in axes:
    for ax in col_axes:
        if i < len(ccaas):
            ccaa = ccaas[i]
            y = df_es[df_es["CCAA"] == ccaa]["Mortality_rate"].values
            
            ipeaks, _ = find_peaks(y)
            
            ax.plot(x, y, color = "k", alpha = 0.7)
            ax.scatter(ipeaks, np.array(y)[ipeaks], color = "red", label = "Picos de mortalidade")
            ax.scatter(x[list(y).index(np.max(y))], np.max(y), color = "k", marker = "o", alpha = 0.7, s = 250, label = "Maximo de mortalidade")
            
            ax.set_title("Mortality rate {}".format(ccaa))
            ax.legend()
            ax.grid()
            i += 1

fig.delaxes(axes[3, 4])

# %%
x = [day for day in range(len(df_it["DATE"].unique()))]

fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(30,20))
# plt.setp(axes, ylim=(0 ,max(df["Mortality rate"])))
ccaas = list(df_it["CCAA"].unique())

i = 0

for col_axes in axes:
    for ax in col_axes:
        if i < len(ccaas):
            ccaa = ccaas[i]
            y = df_it[df_it["CCAA"] == ccaa]["Mortality_rate"].values
            
            ipeaks, _ = find_peaks(y)
            
            ax.plot(x, y, color = "k", alpha = 0.7)
            ax.scatter(ipeaks, np.array(y)[ipeaks], color = "red", label = "Picos de mortalidade")
            ax.scatter(x[list(y).index(np.max(y))], np.max(y), color = "k", marker = "o", alpha = 0.7, s = 250, label = "Maximo de mortalidade")
            
            ax.set_title("Taxa de mortalidade {}".format(ccaa))
            ax.legend()
            ax.grid()
            i += 1

fig.delaxes(axes[3, 4])
